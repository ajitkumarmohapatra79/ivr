# %%
# open file and read the content in a list
with open('ivr_backup_data/order_account_list.txt', 'r') as filehandle:
    order_account_list = [account.rstrip() for account in filehandle.readlines()]

# %%
order_account_list
# Out:
# ['716308354',
#  '2387138088',
#  '2297289602',
#  '2747556495',
#  '3159523017',
#  '2509583',
#  '3757815276',
#  '2363373002',
#  '495945620',
#  '59405613',
#  '784851581',
#  '1944055451',
#  '3793234185',
#  '517589398',
#  '839100889',
#  '1780582893',
#  '3429105445',
#  '2283297866',
#  '1460964230',
#  '2077593863',
#  '769052594',
#  '1269962102',
#  '857571344',
#  '4133197080',
#  '1831314636',
#  '733277462',
#  '1298827458',
#  '3600164751',
#  '1998771732',
#  '3461647717',
#  '849594422',
#  '2113149649',
#  '167469012',
#  '621787901',
#  '3946271192',
#  '2599721138',
#  '1320903225',
#  '3264224576',
#  '2014499312',
#  '3912168641',
#  '399916610',
#  '219813252',
#  '2155065632',
#  '478966601',
#  '197163066',
#  '2841710441',
#  '2969139176',
#  '3091149175',
#  '3029102138',
#  '1010476266',
#  '2514502418',
#  '2552561311',
#  '530416637',
#  '3570791356',
#  '4198784299',
#  '3886084943',
#  '1723096040',
#  '2492966989',
#  '3686456711',
#  '2751112076',
# ...

# %%
with open('ivr_backup_data/ivr_account_list.txt', 'r') as filehandle:
    ivr_account_list = [account.rstrip() for account in filehandle.readlines()]

# %%
ivr_account_list
# Out:
# ['1621175991',
#  '2498988660',
#  '3604397532',
#  '1834516918',
#  '70439012',
#  '2117300146',
#  '1666576091',
#  '914849004',
#  '3465083745',
#  '2536132159',
#  '2870476507',
#  '3876473717',
#  '3652076770',
#  '2077561412',
#  '3160574454',
#  '559619746',
#  '1425407489',
#  '2310864699',
#  '2785003417',
#  '2142028561',
#  '2017067893',
#  '3788513964',
#  '1834855167',
#  '4234739577',
#  '3503820964',
#  '1008692954',
#  '2879950437',
#  '543019229',
#  '1561329892',
#  '2816492404',
#  '2173836781',
#  '612683336',
#  '3827012316',
#  '576853555',
#  '1265644117',
#  '3645566767',
#  '2688429176',
#  '2774304178',
#  '2754828488',
#  '854127117',
#  '3627792481',
#  '1719056038',
#  '1133297439',
#  '4193685164',
#  '453511085',
#  '4032169160',
#  '3341964565',
#  '1346381800',
#  '23927393',
#  '1402011757',
#  '3078982181',
#  '2935093133',
#  '738183774',
#  '4054663094',
#  '184601501',
#  '4204463389',
#  '1211395745',
#  '2263987357',
#  '2999242488',
# ...

# %%
on_both_list = list(set(order_account_list) & (set(ivr_account_list)))

# %%
len(on_both_list)
# Out:
# 43

# %%
on_both_list
# Out:
# ['192566459',
#  '2674318641',
#  '892264564',
#  '378909086',
#  '604308204',
#  '2193192324',
#  '3396675899',
#  '2403059674',
#  '3711636312',
#  '3074745657',
#  '3467416906',
#  '4236039044',
#  '3586325771',
#  '235115601',
#  '775676567',
#  '3940863385',
#  '1016722785',
#  '1568329545',
#  '1418992215',
#  '2026475336',
#  '2817908417',
#  '1465462082',
#  '1143081535',
#  '4239459532',
#  '1099924993',
#  '2200173004',
#  '660481683',
#  '908549264',
#  '2418033983',
#  '2224019690',
#  '2388560788',
#  '3774541304',
#  '3420491810',
#  '3299572099',
#  '3711747260',
#  '3732956597',
#  '908547041',
#  '1902318796',
#  '3501910227',
#  '2451657428',
#  '3971645049',
#  '2713690370',
#  '3646434782']

# %%
with open('ivr_backup_data/order_comcast_account_list.txt', 'r') as filehandle:
    order_comcast_account_list = [account.rstrip() for account in filehandle.readlines()]

# %%
on_both_list_comcast = list(set(order_comcast_account_list) & (set(ivr_account_list)))

# %%
len(on_both_list_comcast)
# Out:
# 40

# %%
with open('ivr_backup_data/ivr_account_number_list.txt', 'r') as filehandle:
    ivr_account_number_list = [account.rstrip() for account in filehandle.readlines()]

# %%
len(list(set(order_account_list) & (set(ivr_account_number_list))))
# Out:
# 0

# %%
len(list(set(order_comcast_account_list) & (set(ivr_account_number_list))))
# Out:
# 0

# %%
with open('ivr_backup_data/ivr_transfer_number_list.txt', 'r') as filehandle:
    ivr_transfer_number_list = [account.rstrip() for account in filehandle.readlines()]

# %%
len(list(set(order_account_list) & (set(ivr_transfer_number_list))))
# Out:
# 0
